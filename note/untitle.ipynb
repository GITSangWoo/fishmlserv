# %%
pip install scikit-learn
# Out:
# /home/centa/code/fishmlserv/.venv/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # data
#
# - https://www.kaggle.com/datasets/vipullrathod/fish-market

# %%
from sklearn.neighbors import KNeighborsClassifier

bream_length = [25.4, 26.3, 26.5, 29.0, 29.0, 29.7, 29.7, 30.0, 30.0, 30.7, 31.0, 31.0, 31.5, 32.0, 32.0, 32.0, 33.0, 33.0, 33.5, 33.5, 34.0, 34.0, 34.5, 35.0, 35.0, 35.0, 35.0, 36.0, 36.0, 37.0, 38.5, 38.5, 39.5, 41.0, 41.0]
bream_weight = [242.0, 290.0, 340.0, 363.0, 430.0, 450.0, 500.0, 390.0, 450.0, 500.0, 475.0, 500.0, 500.0, 340.0, 600.0, 600.0, 700.0, 700.0, 610.0, 650.0, 575.0, 685.0, 620.0, 680.0, 700.0, 725.0, 720.0, 714.0, 850.0, 1000.0, 920.0, 955.0, 925.0, 975.0, 950.0]

smelt_length = [9.8, 10.5, 10.6, 11.0, 11.2, 11.3, 11.8, 11.8, 12.0, 12.2, 12.4, 13.0, 14.3, 15.0]
smelt_weight = [6.7, 7.5, 7.0, 9.7, 9.8, 8.7, 10.0, 9.9, 9.8, 12.2, 13.4, 12.2, 19.7, 19.9]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from sklearn.neighbors import KNeighborsClassifier
#       3 bream_length = [25.4, 26.3, 26.5, 29.0, 29.0, 29.7, 29.7, 30.0, 30.0, 30.7, 31.0, 31.0, 31.5, 32.0, 32.0, 32.0, 33.0, 33.0, 33.5, 33.5, 34.0, 34.0, 34.5, 35.0, 35.0, 35.0, 35.0, 36.0, 36.0, 37.0, 38.5, 38.5, 39.5, 41.0, 41.0]
#       4 bream_weight = [242.0, 290.0, 340.0, 363.0, 430.0, 450.0, 500.0, 390.0, 450.0, 500.0, 475.0, 500.0, 500.0, 340.0, 600.0, 600.0, 700.0, 700.0, 610.0, 650.0, 575.0, 685.0, 620.0, 680.0, 700.0, 725.0, 720.0, 714.0, 850.0, 1000.0, 920.0, 955.0, 925.0, 975.0, 950.0]
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
import matplotlib.pyplot as plt

plt.scatter(bream_length, bream_weight)
plt.xlabel('length')
plt.ylabel('weight')
plt.show()

# %%
plt.scatter(smelt_length, smelt_weight)
plt.xlabel('length')                                                       
plt.ylabel('weight')
plt.show()

# %%
len(bream_length)
# Out:
# 35

# %%
length = bream_length + smelt_length
weight = bream_weight + smelt_weight

fish_data = []

for l, w in zip(length, weight):
    fish_data.append([l, w])

# %%
fish_target = [1] * 35 + [0] * 14

# %%
from sklearn.neighbors import KNeighborsClassifier
kn = KNeighborsClassifier()

# 데이터를 ML 에 먹인다
kn.fit(fish_data, fish_target)
# Out:
# KNeighborsClassifier()

# %%
if kn.predict([[30, 600]])[0] == 1:
    print('도미')
else:
    print('빙어')
# Out:
# 도미

# %%
import pickle
with open("model.pkl", "wb") as f:
    pickle.dump(kn, f)
# Out:
# Running cells with 'Python 3.11.9' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/home/centa/.pyenv/versions/3.11.9/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
### 모델 불러오기
with open("model.pkl", "rb") as f:
    fish_model = pickle.load(f)

fish_model.predict([[30.1, 600.123]])
# Out:
# array([1])

# %%
import matplotlib.pyplot as plt

plt.scatter(bream_length, bream_weight)
plt.xlabel('length')
plt.ylabel('weight')
plt.show()

plt.scatter(smelt_length, smelt_weight)
plt.xlabel('length')
plt.ylabel('weight')
plt.show()

length = bream_length + smelt_length
weight = bream_weight + smelt_weight

len(bream_length)
len(smelt_length)

from sklearn.neighbors import KNeighborsClassifier
kn = KNeighborsClassifier()

fish_data = []

for l, w in zip(length, weight):
    fish_data.append([l, w])

# fish_data = [[l, w] for l, w in zip(length, weight)]

fish_target = [1] * 35 + [0] * 14

# 데이터를 ML 에 먹인다
kn.fit(fish_data, fish_target)

# 예측
r = kn.predict([[30.1, 600.123]])

if kn.predict([[30, 600]])[0] == 1:
    print('도미')
else:
    print('빙어')

### 모델 저장하기
import pickle
with open("model.pkl", "wb") as f:
    pickle.dump(kn, f)

### 모델 불러오기
with open("model.pkl", "rb") as f:
    fish_model = pickle.load(f)

fish_model.predict([[30.1, 600.123]])

# %%
length = bream_length + smelt_length
weight = bream_weight + smelt_weight


from sklearn.neighbors import KNeighborsClassifier
kn = KNeighborsClassifier(n_neighbors=49)

fish_data = []

for l, w in zip(length, weight):
    fish_data.append([l, w])
    

fish_target = [1] * 35 + [0] * 14

# 데이터를 ML 에 먹인다
kn.fit(fish_data, fish_target)

import pickle
with open("model49.pkl", "wb") as f:
    pickle.dump(kn, f)

# %%
plt.scatter(length, weight)
plt.xlabel('length')
plt.ylabel('weight')
plt.show()

# %%
pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 143.5 kB/s eta 0:00:0000:0100:03
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 117.4 kB/s eta 0:00:0000:0100:01
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
val_data=pd.read_csv("/home/centa/data/fish_test_data.csv")

# %%
val_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000000 entries, 0 to 9999999
# Data columns (total 3 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   Length  float64
#  1   Weight  float64
#  2   Label   object
# dtypes: float64(2), object(1)
# memory usage: 228.9+ MB

# %%
val_data.head(5)
# Out:
#       Length      Weight  Label
# 0  39.049430  898.511670  Bream
# 1  12.776059   13.078934  Smelt
# 2  12.761093   18.665042  Smelt
# 3  30.781178  566.790054  Bream
# 4  13.145714    9.207782  Smelt

# %%
val_data['Label'][val_data['Label']=='Bream']=0
val_data['Label'][val_data['Label']=='Smelt']=1
# Out:
# /tmp/ipykernel_1559411/1830774537.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_data['Label'][val_data['Label']=='Bream']=0
# /tmp/ipykernel_1559411/1830774537.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_data['Label'][val_data['Label']=='Smelt']=1

# %%
val_data.head(5)
# Out:
#       Length      Weight Label
# 0  39.049430  898.511670     0
# 1  12.776059   13.078934     1
# 2  12.761093   18.665042     1
# 3  30.781178  566.790054     0
# 4  13.145714    9.207782     1

# %%
val_LW.head(6)
# Out:
#       Length      Weight
# 0  39.049430  898.511670
# 1  12.776059   13.078934
# 2  12.761093   18.665042
# 3  30.781178  566.790054
# 4  13.145714    9.207782
# 5  27.811040  399.267497

# %%
val_ans
# Out:
# 0          0
# 1          1
# 2          1
# 3          0
# 4          1
#           ..
# 9999995    0
# 9999996    1
# 9999997    1
# 9999998    0
# 9999999    0
# Name: Label, Length: 10000000, dtype: int64

# %%
with open("model.pkl", "rb") as f:
    fish_model = pickle.load(f)
    
pred1=fish_model.predict(val_LW)
# Out:
# /home/centa/.pyenv/versions/3.8.19/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(

# %%
from sklearn.metrics import confusion_matrix

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(val_ans,pred1)
# Out:
# array([[      0, 5000383],
#        [4999617,       0]])

# %%
import matplotlib.pyplot as plt

plt.scatter(bream_length, bream_weight)
plt.xlabel('length')
plt.ylabel('weight')
plt.show()

# %%
import requests
import json 

headers = {
    'accept': 'application/json',
}

params = {
    'length': '40',
    'weight': '300',
}

response = requests.get('http://127.0.0.1:8000/fish_ml_predictor', params=params, headers=headers)
A= data = json.loads(response.text)
B=A['prediction']
B
# Out:
# 'Bream'

# %%
import requests
import json 

headers = {
    'accept': 'application/json',
}
repred=[]
for i in range(10):
    params = {
    'length': val_LW['Length'][i],
    'weight': val_LW['Weight'][i],
    }
    response = requests.get('http://127.0.0.1:8000/fish_ml_predictor', params=params, headers=headers)
    data=json.loads(response.text)
    repred.append(data['prediction'])

print(repred)

test_df=val_LW[:20]
# Out:
# ['Bream', 'Smelt', 'Smelt', 'Bream', 'Smelt', 'Bream', 'Smelt', 'Bream', 'Smelt', 'Bream', 'Smelt', 'Smelt', 'Bream', 'Smelt', 'Bream', 'Bream', 'Smelt', 'Smelt', 'Smelt', 'Smelt']

# %%
import requests
import json 
val_data_cut=val_data[:4000]
headers = {
    'accept': 'application/json',
}
repred=[]
for i in range(len(val_data_cut)):
    params = {
    'length': val_data['Length'][i],
    'weight': val_data['Weight'][i],
    }
    response = requests.get('http://127.0.0.1:8000/fish_ml_predictor', params=params, headers=headers)
    data=json.loads(response.text)
    if data['prediction'] == '도미':
        repred.append(0)
    else :
        repred.append(1)
val_data_cut['pred_result']=repred
# Out:
# /tmp/ipykernel_1559411/651186114.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_data_cut['pred_result']=repred

# %%
val_data_cut
# Out:
#          Length      Weight Label  pred_result
# 0     39.049430  898.511670     0            0
# 1     12.776059   13.078934     1            1
# 2     12.761093   18.665042     1            1
# 3     30.781178  566.790054     0            0
# 4     13.145714    9.207782     1            1
# ...         ...         ...   ...          ...
# 3995  14.449989   11.697466     1            1
# 3996  32.550132  548.613724     0            0
# 3997  40.820039  937.479740     0            0
# 3998  31.095114  928.537411     0            0
# 3999  14.016731    8.615061     1            1
#
# [4000 rows x 4 columns]

# %%
len(val_data)
# Out:
# 10000000

# %%
test_df['result']=repred
test_df
# Out:
# /tmp/ipykernel_926699/72185873.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['result']=repred
#        Length      Weight result
# 0   39.049430  898.511670  Bream
# 1   12.776059   13.078934  Smelt
# 2   12.761093   18.665042  Smelt
# 3   30.781178  566.790054  Bream
# 4   13.145714    9.207782  Smelt
# 5   27.811040  399.267497  Bream
# 6   12.365433   15.052020  Smelt
# 7   36.960181  850.632495  Bream
# 8   14.180343   18.951007  Smelt
# 9   30.833793  398.105400  Bream
# 10  14.747958   16.917001  Smelt
# 11  11.245199   17.586762  Smelt
# 12  34.642483  559.542595  Bream
# 13  12.373865    9.694479  Smelt
# 14  29.587144  832.024188  Bream
# 15  32.073452  604.946938  Bream
# 16  11.679827   17.945186  Smelt
# ...

# %%
val_LW['Length'][1]
# Out:
# 12.776058660753328

# %%
val_LW.head(2)
# Out:
#       Length      Weight
# 0  39.049430  898.511670
# 1  12.776059   13.078934

# %%
val_LW['Weight'][1]
# Out:
# 13.07893388816564

# %%
len(val_data)
# Out:
# 10000000

# %%
pip install pyarrow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 MB 9.2 MB/s eta 0:00:00:00:010:01m
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pdf=pd.read_parquet("/home/centa/data/fish_pred_parquet/")
pdf
# Out:
#           Length      Weight  Label  pred_result
# 0      39.049430  898.511670      0            0
# 1      12.776059   13.078934      1            1
# 2      12.761093   18.665042      1            1
# 3      30.781178  566.790054      0            0
# 4      13.145714    9.207782      1            1
# ...          ...         ...    ...          ...
# 99995  12.447209    9.188887      1            1
# 99996  31.082503  389.510045      0            0
# 99997  13.950318   13.861875      1            1
# 99998  32.331884  398.421333      0            0
# 99999  35.699531  667.653606      0            0
#
# [100000 rows x 4 columns]

# %%
pdf
pdf[pdf['Label']==0]
# Out:
#          Length      Weight  Label  pred_result
# 0     39.049430  898.511670      0            0
# 3     30.781178  566.790054      0            0
# 5     27.811040  399.267497      0            0
# 7     36.960181  850.632495      0            0
# 9     30.833793  398.105400      0            0
# ...         ...         ...    ...          ...
# 9993  27.259318  442.724654      0            0
# 9995  27.762058  522.030728      0            0
# 9996  31.079464  957.075340      0            0
# 9997  35.176039  366.399998      0            0
# 9999  26.807165  448.216818      0            0
#
# [5044 rows x 4 columns]

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(pdf['Label'],pdf['pred_result'])
cm
# Out:
# array([[2538,    0],
#        [   0, 2462]])

# %%
Real=['Real_Bream','Real_Smelt'] 
pred=['pred_Bream','pred_Smelt'] 
cm_df = pd.DataFrame(cm, index=Real, columns=pred)
cm_df
# Out:
#             pred_Bream  pred_Smelt
# Real_Bream        2538           0
# Real_Smelt           0        2462

# %%
agg_df=pd.read_parquet("/home/centa/data/fish_agg_parquet")
agg_df
# Out:
#             pred_Bream  pred_Smelt
# Real_Bream       50007           0
# Real_Smelt           0       49993

# %%
test_df=pd.read_parquet("/home/centa/data/fish_parquet")
test_df
# Out:
#             Length      Weight  Label
# 0        39.049430  898.511670      0
# 1        12.776059   13.078934      1
# 2        12.761093   18.665042      1
# 3        30.781178  566.790054      0
# 4        13.145714    9.207782      1
# ...            ...         ...    ...
# 9999995  34.636377  554.759082      0
# 9999996  13.172821   17.191087      1
# 9999997  12.877214   15.103945      1
# 9999998  39.071152  379.180396      0
# 9999999  32.942495  732.028292      0
#
# [10000000 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

plt.scatter(length, weight)
plt.scatter( 25 , 150 , marker='*' )
plt.scatter( 30 , 176 , marker='^' )
plt.xlabel('length')
plt.ylabel('weight')
plt.show()

# %%
with open("model.pkl", "rb") as f:
        fish_model = pickle.load(f)
l= 400
w= 200
    # 예측 수행
result = fish_model.predict([[l, w]])
print(result)
if result == 1:
    typer.echo("도미")
else:
    typer.echo("빙어")
# Out:
# [1]
# 도미

# %%
import pandas as pd

# %%
test_df=pd.read_csv("/home/centa/data/fish_test_data.csv")

# %%
test_df
# Out:
#             Length      Weight  Label
# 0        39.049430  898.511670  Bream
# 1        12.776059   13.078934  Smelt
# 2        12.761093   18.665042  Smelt
# 3        30.781178  566.790054  Bream
# 4        13.145714    9.207782  Smelt
# ...            ...         ...    ...
# 9999995  34.636377  554.759082  Bream
# 9999996  13.172821   17.191087  Smelt
# 9999997  12.877214   15.103945  Smelt
# 9999998  39.071152  379.180396  Bream
# 9999999  32.942495  732.028292  Bream
#
# [10000000 rows x 3 columns]

# %%
import pandas as pd

# %%
test1_df=pd.read_parquet("/home/centa/data/fish_pred_parquet/fish_pred1.parquet")
test1_df
# Out:
#           Length      Weight  Label     k1
# 0      39.049430  898.511670      0  Bream
# 1      12.776059   13.078934      1  Smelt
# 2      12.761093   18.665042      1  Smelt
# 3      30.781178  566.790054      0  Bream
# 4      13.145714    9.207782      1  Smelt
# ...          ...         ...    ...    ...
# 99995  12.447209    9.188887      1  Smelt
# 99996  31.082503  389.510045      0  Bream
# 99997  13.950318   13.861875      1  Smelt
# 99998  32.331884  398.421333      0  Bream
# 99999  35.699531  667.653606      0  Bream
#
# [100000 rows x 4 columns]

# %%
test2_df=pd.read_parquet("/home/centa/data/fish_parquet/fish_test_data.parquet")

# %%
test2_df
# Out:
#         Length      Weight  Label     k1     k5    k15    k25    k49
# 0    39.049430  898.511670  Bream  Bream  Bream  Bream  Bream  Bream
# 1    12.776059   13.078934  Smelt  Smelt  Smelt  Smelt  Smelt  Bream
# 2    12.761093   18.665042  Smelt  Smelt  Smelt  Smelt  Smelt  Bream
# 3    30.781178  566.790054  Bream  Bream  Bream  Bream  Bream  Bream
# 4    13.145714    9.207782  Smelt  Smelt  Smelt  Smelt  Smelt  Bream
# ..         ...         ...    ...    ...    ...    ...    ...    ...
# 995  32.063407  302.463392  Bream  Bream  Bream  Bream  Bream  Bream
# 996  37.533722  881.436450  Bream  Bream  Bream  Bream  Bream  Bream
# 997  35.957612  893.336675  Bream  Bream  Bream  Bream  Bream  Bream
# 998  33.277384  765.675503  Bream  Bream  Bream  Bream  Bream  Bream
# 999  10.214480    6.735782  Smelt  Smelt  Smelt  Smelt  Smelt  Bream
#
# [1000 rows x 8 columns]

# %%
val_data
# Out:
#         Length      Weight Label     k1 k5    k15    k25    k49
# 0    39.049430  898.511670     0  Bream  0  Bream  Bream  Bream
# 1    12.776059   13.078934     1  Smelt  1  Smelt  Smelt  Bream
# 2    12.761093   18.665042     1  Smelt  1  Smelt  Smelt  Bream
# 3    30.781178  566.790054     0  Bream  0  Bream  Bream  Bream
# 4    13.145714    9.207782     1  Smelt  1  Smelt  Smelt  Bream
# ..         ...         ...   ...    ... ..    ...    ...    ...
# 995  32.063407  302.463392     0  Bream  0  Bream  Bream  Bream
# 996  37.533722  881.436450     0  Bream  0  Bream  Bream  Bream
# 997  35.957612  893.336675     0  Bream  0  Bream  Bream  Bream
# 998  33.277384  765.675503     0  Bream  0  Bream  Bream  Bream
# 999  10.214480    6.735782     1  Smelt  1  Smelt  Smelt  Bream
#
# [1000 rows x 8 columns]

# %%
val_data['k5']
val_data.loc[val_data[f'k{i}']=='Smelt',f"k{i}"]=1
# Out:
# 0      Bream
# 1      Smelt
# 2      Smelt
# 3      Bream
# 4      Smelt
#        ...
# 995    Bream
# 996    Bream
# 997    Bream
# 998    Bream
# 999    Smelt
# Name: k5, Length: 1000, dtype: object

# %%
val_data.iloc[val_data[f'k{i}']=='Smelt,[:,3:8]]
# Out:
#         k1 k5    k15    k25    k49
# 0    Bream  0  Bream  Bream  Bream
# 1    Smelt  1  Smelt  Smelt  Bream
# 2    Smelt  1  Smelt  Smelt  Bream
# 3    Bream  0  Bream  Bream  Bream
# 4    Smelt  1  Smelt  Smelt  Bream
# ..     ... ..    ...    ...    ...
# 995  Bream  0  Bream  Bream  Bream
# 996  Bream  0  Bream  Bream  Bream
# 997  Bream  0  Bream  Bream  Bream
# 998  Bream  0  Bream  Bream  Bream
# 999  Smelt  1  Smelt  Smelt  Bream
#
# [1000 rows x 5 columns]

# %%
val_data['Label']
val_data.loc[col_name]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 2
#       1 val_data['Label']
# ----> 2 val_data.loc[col_name]
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/pandas/core/indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/pandas/core/indexing.py:1381, in _LocIndexer._get_label(self, label, axis)
# ...

# %%
val_data.loc[val_data['Label']=='Bream',"Label"]=0
val_data.loc[val_data['Label']=='Smelt',"Label"]=1

# %%
val_data=pd.read_parquet("/home/centa/data/fish_pred_parquet/fish_pred49.parquet")

# %%
from sklearn.metrics import confusion_matrix

# %%
val_data
val_data.replace({'Bream': 0, 'Smelt': 1}, inplace=True)
# Out:
# /tmp/ipykernel_1926024/3126595860.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   val_data.replace({'Bream': 0, 'Smelt': 1}, inplace=True)

# %%
 val_data
# Out:
#         Length      Weight  Label  k1  k5  k15  k25  k49
# 0    39.049430  898.511670      0   0   0    0    0    0
# 1    12.776059   13.078934      1   1   1    1    1    0
# 2    12.761093   18.665042      1   1   1    1    1    0
# 3    30.781178  566.790054      0   0   0    0    0    0
# 4    13.145714    9.207782      1   1   1    1    1    0
# ..         ...         ...    ...  ..  ..  ...  ...  ...
# 995  32.063407  302.463392      0   0   0    0    0    0
# 996  37.533722  881.436450      0   0   0    0    0    0
# 997  35.957612  893.336675      0   0   0    0    0    0
# 998  33.277384  765.675503      0   0   0    0    0    0
# 999  10.214480    6.735782      1   1   1    1    1    0
#
# [1000 rows x 8 columns]

# %%
cm=confusion_matrix(val_data.iloc[:,3],val_data.iloc[:,4])
cm
# Out:
# array([[509,   0],
#        [  0, 491]])

# %%
for i in range(4,8):
    cm=confusion_matrix(val_data.iloc[:,3],val_data.iloc[:,i])
    Real=['Real_Bream','Real_Smelt']
    pred=['pred_Bream','pred_Smelt']
    cm_df = pd.DataFrame(cm, index=Real, columns=pred)
    print(cm_df)
# Out:
#             pred_Bream  pred_Smelt
# Real_Bream         509           0
# Real_Smelt           0         491
#             pred_Bream  pred_Smelt
# Real_Bream         509           0
# Real_Smelt           0         491
#             pred_Bream  pred_Smelt
# Real_Bream         502           7
# Real_Smelt           0         491
#             pred_Bream  pred_Smelt
# Real_Bream         509           0
# Real_Smelt         491           0
